# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy
import tensorflow as tf

numpy.random.seed(777)
tf.random.set_seed(777)

df = pd.read_csv('iris.csv')
dataset = df.values
x_data = dataset[:,0:4].astype(float) # 특성
y_data = dataset[:,4] # 정답

e = LabelEncoder() # I0: 0, I1: 1, I2:2
e.fit(y_data)
y_data = e.transform(y_data)
y_encoded = to_categorical(y_data) # to_categorical => make one-hot encoding


model = Sequential()
model.add(Dense(20,  input_dim=4, activation='relu'))
model.add(Dense(3, activation='softmax'))

model.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

model.fit(x_data, y_encoded, epochs=50, batch_size=5)

result = model.evaluate(x_data, y_encoded)
print("\n loss: %.4f" % (result[0]))
print("\n Accuracy: %.4f" % (result[1]))
# Out:
# Epoch 1/50
# 30/30 [==============================] - 0s 755us/step - loss: 1.3296 - accuracy: 0.3758
# Epoch 2/50
# 30/30 [==============================] - 0s 700us/step - loss: 1.1703 - accuracy: 0.4295
# Epoch 3/50
# 30/30 [==============================] - 0s 726us/step - loss: 1.0233 - accuracy: 0.4094
# Epoch 4/50
# 30/30 [==============================] - 0s 682us/step - loss: 0.9116 - accuracy: 0.6711
# Epoch 5/50
# 30/30 [==============================] - 0s 636us/step - loss: 0.8136 - accuracy: 0.7785
# Epoch 6/50
# 30/30 [==============================] - 0s 707us/step - loss: 0.7416 - accuracy: 0.7785
# Epoch 7/50
# 30/30 [==============================] - 0s 691us/step - loss: 0.6831 - accuracy: 0.8188
# Epoch 8/50
# 30/30 [==============================] - 0s 697us/step - loss: 0.6362 - accuracy: 0.8054
# Epoch 9/50
# 30/30 [==============================] - 0s 738us/step - loss: 0.5987 - accuracy: 0.8255
# Epoch 10/50
# ...
